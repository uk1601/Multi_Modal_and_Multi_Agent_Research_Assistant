# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
#from aws_s3 import save_image, download_pdf
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options

# Base URL for the first page
base_url = "https://rpc.cfainstitute.org/en/research-foundation/publications"

# Base domain to construct full URLs for PDFs and images
base_domain = "https://rpc.cfainstitute.org"

# Default alternative image URL
alternative_image_url = "https://media.istockphoto.com/id/1352945762/vector/no-image-available-like-missing-picture.jpg?s=612x612&w=0&k=20&c=4X-znbt02a8EIdxwDFaxfmKvUhTnLvLMv1i1f3bToog="

# Initialize the Selenium WebDriver
chrome_options = Options()
chrome_options.add_argument("--headless")
# chrome_options.add_argument("--no-sandbox")
# chrome_options.add_argument("--disable-dev-shm-usage")

# Connect to the remote Selenium server
driver = webdriver.Chrome(
    options=chrome_options
)

# %%
# Define a global ID counter outside the functions
global_id_counter = 1

def get_publications_from_page(page_url):
    global global_id_counter  # Declare as global to update across function calls

    # List to store publication data
    publications_data = []
    # Load the page using Selenium
    driver.get(page_url)
    time.sleep(5)  # Wait for the page to fully load

    # Get the page content and pass it to BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    publications = soup.find_all('div', class_='coveo-list-layout CoveoResult')
    publications=publications[:3]

    for publication in publications:
        # Get the title and link
        title_tag = publication.find('h4', class_='coveo-title').find('a', class_='CoveoResultLink')
        if title_tag:
            title = title_tag.text.strip()
            publication_link = title_tag['href']
        else:
            print(f"No title available for publication: {len(publications_data)+1}")
            continue

        # Extract the summary text
        summary_tag = publication.find('div', class_='result-body')
        summary = summary_tag.text.strip() if summary_tag else "No summary available"

        # Extract the image URL
        result_link_div = publication.find('div', class_='result-link')
        if result_link_div:
            image_tag = result_link_div.find('img', class_='coveo-result-image')
            image_url = base_domain + image_tag['src'] if image_tag else alternative_image_url
            image_path = save_image(title, image_url)
        else:
            image_url = alternative_image_url
            image_path = save_image(title, image_url)

        # Visit the publication page to extract the PDF link
        driver.get(publication_link)
        time.sleep(3)
        publication_soup = BeautifulSoup(driver.page_source, 'html.parser')
        pdf_link_tag = publication_soup.find('a', href=lambda href: href and href.endswith('.pdf'))
        pdf_url = base_domain + pdf_link_tag['href'] if pdf_link_tag else "No PDF found"
        pdf_path = download_pdf(title, pdf_url)

        # Append data to publications_data
        publications_data.append({
            "ID": global_id_counter,
            "Title": title,
            "Summary": summary,
            "Image Path": image_path,
            "PDF Path": pdf_path
        })

        # Output the extracted information
        print(f"ID:{global_id_counter}")
        print(f"Title: {title}")
        print(f"Summary: {summary}")
        print(f"Image Path: {image_path}")
        print(f"Publication Link: {publication_link}")
        print(f"PDF Path: {pdf_path}")
        print("-" * 100)
        global_id_counter += 1  # Increment the global ID counter
    # Convert the publications_data list to a DataFrame
    publications_df = pd.DataFrame(publications_data, columns=["ID", "Title", "Summary", "Image Path", "PDF Path"])
    return publications_df

# %%
import os
import requests

def download_pdf(title, pdf_url):
    try:
        response = requests.get(pdf_url)
        response.raise_for_status()

        if response.content:  # Ensure response has content
            # Define local path for saving the PDF
            local_path = f"pdfs/{sanitize_filename(title)}.pdf"
            os.makedirs(os.path.dirname(local_path), exist_ok=True)
            
            # Write content to a local PDF file
            with open(local_path, "wb") as pdf_file:
                pdf_file.write(response.content)
                
            print(f"PDF saved locally as {local_path}")
            return local_path
        else:
            print(f"No content in PDF for {title}.")
            return ""
    except Exception as e:
        print(f"Failed to download PDF for {title}. Error: {e}")
        return ""

def save_image(title, image_url):
    try:
        response = requests.get(image_url)
        response.raise_for_status()
        
        if response.content:  # Ensure response has content
            # Define local path for saving the image
            local_path = f"images/{sanitize_filename(title)}.jpg"
            os.makedirs(os.path.dirname(local_path), exist_ok=True)
            
            # Write content to a local image file
            with open(local_path, "wb") as image_file:
                image_file.write(response.content)
                
            print(f"Image saved locally as {local_path}")
            return local_path
        else:
            print(f"No content in image for {title}.")
            return ""
    except Exception as e:
        print(f"Failed to save image for {title}. Error: {e}")
        return ""

def sanitize_filename(name):
    return "".join([c if c.isalnum() or c in " ._-()" else "_" for c in name])

# %%
def scrape_publications():
    total_pages = 1  # Adjust the number of pages
    all_publications_df = pd.DataFrame(columns=["ID", "Title", "Summary", "Image Path", "PDF Path"])
    for page_number in range(1, total_pages + 1):
        page_url = f"{base_url}#first={(page_number - 1) * 10}"
        print(f"\n{'-'*100}\nScraping page {page_number}: {page_url}\n{'-'*100}\n")
        # Get the DataFrame for each page and append it to the main DataFrame
        page_df = get_publications_from_page(page_url)
        all_publications_df = pd.concat([all_publications_df, page_df], ignore_index=True)

    # all_publications_df.to_csv("publications_data.csv", index=False)
    # print("Data saved to publications_data.csv")
    return all_publications_df

# Close the Selenium browser after scraping
def close_driver():
    driver.quit()

# %%
df= scrape_publications()
close_driver()
df

# %%
from docling.document_converter import DocumentConverter

source = "./pdfs/Beyond Active and Passive Investing_ The Customization of Finance.pdf"  # PDF path or URL
converter = DocumentConverter()
result = converter.convert(source)
markdown_content=result.document.export_to_markdown()

def save_markdown_to_readme(markdown_content, output_path="./extracted.md"):
    # Write the Markdown content to README.md
    with open(output_path, "w") as file:
        file.write(markdown_content)
    print(f"Markdown content saved to {output_path}")

save_markdown_to_readme(markdown_content)

# %%
import json
import logging
import time
from pathlib import Path
from typing import Iterable

from docling.datamodel.base_models import ConversionStatus
from docling.datamodel.document import ConversionResult
from docling.datamodel.settings import settings
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
#from docling.datamodel.base_models import ImageRefMode, PictureItem, TableItem
from docling.datamodel import base_models
# Setup logging
logging.basicConfig(level=logging.INFO)
_log = logging.getLogger(__name__)

# Set image resolution for extracted images
IMAGE_RESOLUTION_SCALE = 2.0

def export_images_and_tables(conv_res, output_dir, doc_filename):
    """Save images and tables from the document."""
    # Create output directory if not exists
    output_dir.mkdir(parents=True, exist_ok=True)

    # Save page images
    for page_no, page in conv_res.document.pages.items():
        page_image_filename = output_dir / f"{doc_filename}-page-{page_no}.png"
        with page_image_filename.open("wb") as fp:
            page.image.pil_image.save(fp, format="PNG")

    # Save images of figures and tables
    table_counter = 0
    picture_counter = 0
    for element, _ in conv_res.document.iterate_items():
        if isinstance(element, base_models.TableItem):
            table_counter += 1
            table_image_filename = output_dir / f"{doc_filename}-table-{table_counter}.png"
            with table_image_filename.open("wb") as fp:
                element.image.pil_image.save(fp, "PNG")
        elif isinstance(element, base_models.PictureItem):
            picture_counter += 1
            picture_image_filename = output_dir / f"{doc_filename}-picture-{picture_counter}.png"
            with picture_image_filename.open("wb") as fp:
                element.image.pil_image.save(fp, "PNG")

def export_documents(conv_results: Iterable[ConversionResult], output_dir: Path):
    """Export document metadata and images for each document."""
    output_dir.mkdir(parents=True, exist_ok=True)

    # Track the status of document conversions
    success_count = 0
    failure_count = 0
    partial_success_count = 0

    for conv_res in conv_results:
        doc_filename = conv_res.input.file.stem

        if conv_res.status == ConversionStatus.SUCCESS:
            success_count += 1

            # Export document to JSON
            with (output_dir / f"{doc_filename}.json").open("w") as fp:
                json.dump(conv_res.document.export_to_dict(), fp)

            # Export document to Markdown with embedded images
            #with (output_dir / f"{doc_filename}.md").open("w") as fp:
            #    fp.write(conv_res.document.export_to_markdown(image_mode=base_models.ImageRefMode.EMBEDDED))

            # Save images and tables
            export_images_and_tables(conv_res, output_dir / "images", doc_filename)

        elif conv_res.status == ConversionStatus.PARTIAL_SUCCESS:
            partial_success_count += 1
            _log.warning(f"Partial success for {doc_filename} with errors:")
            for item in conv_res.errors:
                _log.warning(f"\t{item.error_message}")

        else:
            failure_count += 1
            _log.error(f"Failed to convert {doc_filename}.")

    # Logging final counts of conversion results
    _log.info(f"Processed {success_count + partial_success_count + failure_count} documents.")
    _log.info(f"{success_count} successful, {partial_success_count} partially successful, {failure_count} failed.")

    return success_count, partial_success_count, failure_count

def main():
    # Path to your PDF files
    input_doc_paths = [
        Path("./pdfs/Beyond Active and Passive Investing_ The Customization of Finance.pdf"),
        Path("./pdfs/Investment Model Validation_ A Guide for Practitioners.pdf"),
        Path("./pdfs/The Economics of Private Equity_ A Critical Review.pdf")
    ]

    # Configure PDF conversion options for images
    pipeline_options = PdfPipelineOptions()
    pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
    pipeline_options.generate_page_images = True
    pipeline_options.generate_table_images = True
    pipeline_options.generate_picture_images = True

    # Initialize the DocumentConverter with custom pipeline options
    doc_converter = DocumentConverter(
        format_options={
            "pdf": PdfFormatOption(pipeline_options=pipeline_options)
        }
    )

    # Start batch conversion
    start_time = time.time()
    conv_results = doc_converter.convert_all(input_doc_paths, raises_on_error=False)
    export_documents(conv_results, output_dir=Path("output"))

    # Log time taken for conversion
    end_time = time.time() - start_time
    _log.info(f"Batch processing complete in {end_time:.2f} seconds.")

if __name__ == "__main__":
    main()

# %%
import json
import logging
import time
from pathlib import Path
from typing import Iterable

from docling.datamodel.base_models import ConversionStatus
from docling.datamodel.document import ConversionResult
from docling.datamodel.settings import settings
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
#from docling.datamodel.base_models import ImageRefMode, PictureItem, TableItem
from docling.datamodel import base_models
# Setup logging
logging.basicConfig(level=logging.INFO)
_log = logging.getLogger(__name__)

# Set image resolution for extracted images
IMAGE_RESOLUTION_SCALE = 2.0

def export_images_and_tables(conv_res, output_dir, doc_filename):
    """Save images and tables from the document."""
    # Create output directory if not exists
    output_dir.mkdir(parents=True, exist_ok=True)

    # Save page images
    for page_no, page in conv_res.document.pages.items():
        page_image_filename = output_dir / f"{doc_filename}-page-{page_no}.png"
        with page_image_filename.open("wb") as fp:
            page.image.pil_image.save(fp, format="PNG")

    # Save images of figures and tables
    table_counter = 0
    picture_counter = 0
    for element, _ in conv_res.document.iterate_items():
        if isinstance(element, base_models.TableItem):
            table_counter += 1
            table_image_filename = output_dir / f"{doc_filename}-table-{table_counter}.png"
            with table_image_filename.open("wb") as fp:
                element.image.pil_image.save(fp, "PNG")
        elif isinstance(element, base_models.PictureItem):
            picture_counter += 1
            picture_image_filename = output_dir / f"{doc_filename}-picture-{picture_counter}.png"
            with picture_image_filename.open("wb") as fp:
                element.image.pil_image.save(fp, "PNG")

def export_documents(conv_results: Iterable[ConversionResult], output_dir: Path):
    """Export document metadata and images for each document."""
    output_dir.mkdir(parents=True, exist_ok=True)

    success_count = 0
    failure_count = 0
    partial_success_count = 0

    for conv_res in conv_results:
        doc_filename = conv_res.input.file.stem

        if conv_res.status == ConversionStatus.SUCCESS:
            success_count += 1

            # Export document to JSON
            with (output_dir / f"{doc_filename}.json").open("w") as fp:
                json.dump(conv_res.document.export_to_dict(), fp)

            # Export document to Markdown, fallback if ImageRefMode.EMBEDDED is unavailable
            with (output_dir / f"{doc_filename}.md").open("w") as fp:
                try:
                    fp.write(conv_res.document.export_to_markdown(image_mode=base_models.ImageRefMode.EMBEDDED))
                except AttributeError:
                    _log.warning(f"Failed to use ImageRefMode.EMBEDDED for {doc_filename}. Exporting without embedded images.")
                    fp.write(conv_res.document.export_to_markdown())

            # Save images and tables
            export_images_and_tables(conv_res, output_dir / "images", doc_filename)

        elif conv_res.status == ConversionStatus.PARTIAL_SUCCESS:
            partial_success_count += 1
            _log.warning(f"Partial success for {doc_filename} with errors:")
            for item in conv_res.errors:
                _log.warning(f"\t{item.error_message}")

        else:
            failure_count += 1
            _log.error(f"Failed to convert {doc_filename}.")

    _log.info(f"Processed {success_count + partial_success_count + failure_count} documents.")
    _log.info(f"{success_count} successful, {partial_success_count} partially successful, {failure_count} failed.")

    return success_count, partial_success_count, failure_count


def main():
    # Path to your PDF files
    input_doc_paths = [
        Path("./pdfs/Beyond Active and Passive Investing_ The Customization of Finance.pdf"),
        Path("./pdfs/Investment Model Validation_ A Guide for Practitioners.pdf"),
        Path("./pdfs/The Economics of Private Equity_ A Critical Review.pdf")
    ]

    # Configure PDF conversion options for images
    pipeline_options = PdfPipelineOptions()
    pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
    pipeline_options.generate_page_images = True
    pipeline_options.generate_table_images = True
    pipeline_options.generate_picture_images = True

    # Initialize the DocumentConverter with custom pipeline options
    doc_converter = DocumentConverter(
        format_options={
            "pdf": PdfFormatOption(pipeline_options=pipeline_options)
        }
    )

    # Start batch conversion
    start_time = time.time()
    conv_results = doc_converter.convert_all(input_doc_paths, raises_on_error=False)
    export_documents(conv_results, output_dir=Path("output"))

    # Log time taken for conversion
    end_time = time.time() - start_time
    _log.info(f"Batch processing complete in {end_time:.2f} seconds.")

if __name__ == "__main__":
    main()

# %%
import json
import logging
import time
from pathlib import Path

from docling.datamodel.base_models import ConversionStatus
from docling.datamodel.document import ConversionResult
from docling.datamodel.settings import settings
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
#from docling.datamodel.base_models import ImageRefMode, PictureItem, TableItem
from docling.datamodel import base_models
# Setup logging
logging.basicConfig(level=logging.INFO)
_log = logging.getLogger(__name__)

# Set image resolution for extracted images
IMAGE_RESOLUTION_SCALE = 2.0

def export_images_and_tables(conv_res, output_dir, doc_filename):
    """Save images and tables from the document."""
    # Create output directory if it doesn't exist
    output_dir.mkdir(parents=True, exist_ok=True)

    # Save page images
    for page_no, page in conv_res.document.pages.items():
        page_image_filename = output_dir / f"{doc_filename}-page-{page_no}.png"
        with page_image_filename.open("wb") as fp:
            page.image.pil_image.save(fp, format="PNG")

    # Save images of figures and tables
    table_counter = 0
    picture_counter = 0
    for element, _ in conv_res.document.iterate_items():
        if isinstance(element, base_models.TableItem):
            table_counter += 1
            table_image_filename = output_dir / f"{doc_filename}-table-{table_counter}.png"
            with table_image_filename.open("wb") as fp:
                element.image.pil_image.save(fp, "PNG")
        elif isinstance(element, base_models.PictureItem):
            picture_counter += 1
            picture_image_filename = output_dir / f"{doc_filename}-picture-{picture_counter}.png"
            with picture_image_filename.open("wb") as fp:
                element.image.pil_image.save(fp, "PNG")

def export_document(conv_res, output_dir):
    """Export document metadata and images for a single document."""
    output_dir.mkdir(parents=True, exist_ok=True)

    doc_filename = conv_res.input.file.stem

    if conv_res.status == ConversionStatus.SUCCESS:
        # Export document to JSON
        with (output_dir / f"{doc_filename}.json").open("w") as fp:
            json.dump(conv_res.document.export_to_dict(), fp)

        # Export document to Markdown with embedded images
        with (output_dir / f"{doc_filename}.md").open("w") as fp:
            fp.write(conv_res.document.export_to_markdown(image_mode=base_models.ImageRefMode.EMBEDDED))

        # Save images and tables
        export_images_and_tables(conv_res, output_dir / "images", doc_filename)
        _log.info(f"Successfully processed and exported '{doc_filename}'")

    elif conv_res.status == ConversionStatus.PARTIAL_SUCCESS:
        _log.warning(f"Partial success for '{doc_filename}' with errors:")
        for item in conv_res.errors:
            _log.warning(f"\t{item.error_message}")
    else:
        _log.error(f"Failed to convert '{doc_filename}'.")

def main():
    # Path to your PDF files
    input_doc_paths = [
        Path("./pdfs/Beyond Active and Passive Investing_ The Customization of Finance.pdf"),
        Path("./pdfs/Investment Model Validation_ A Guide for Practitioners.pdf"),
        Path("./pdfs/The Economics of Private Equity_ A Critical Review.pdf")
    ]

    # Configure PDF conversion options for images
    pipeline_options = PdfPipelineOptions()
    pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
    pipeline_options.generate_page_images = False
    pipeline_options.generate_table_images = True
    pipeline_options.generate_picture_images = True

    # Initialize the DocumentConverter with custom pipeline options
    doc_converter = DocumentConverter(
        format_options={
            "pdf": PdfFormatOption(pipeline_options=pipeline_options)
        }
    )

    # Process each document individually in a loop
    for pdf_path in input_doc_paths:
        start_time = time.time()
        print(f"-"*40)
        print(f"PDF PATH:{pdf_path}\n")
        _log.info(f"Processing '{pdf_path.name}'...")

        # Convert the document
        conv_res = doc_converter.convert(pdf_path)

        # Export the document content, images, and tables
        export_document(conv_res, output_dir=Path("output"))

        # Log time taken for each document
        end_time = time.time() - start_time
        _log.info(f"Finished processing '{pdf_path.name}' in {end_time:.2f} seconds.")

if __name__ == "__main__":
    main()

# %%
import json
import logging
import time
from pathlib import Path
from typing import Iterable

from docling.datamodel.base_models import ConversionStatus, FigureElement, InputFormat, Table
from docling.datamodel.document import ConversionResult
from docling.datamodel.settings import settings
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling_core.types.doc import ImageRefMode, PictureItem, TableItem
from docling.datamodel.pipeline_options import PdfPipelineOptions


_log = logging.getLogger(__name__)
USE_V2 = True
IMAGE_RESOLUTION_SCALE = 2.0

# %%
def export_documents(
    conv_results: Iterable[ConversionResult],
    output_dir: Path,
):
    output_dir.mkdir(parents=True, exist_ok=True)

    success_count = 0
    failure_count = 0
    partial_success_count = 0

    for conv_res in conv_results:
        if conv_res.status == ConversionStatus.SUCCESS:
            success_count += 1
            doc_filename = conv_res.input.file.stem

            if USE_V2:
                # Export Docling document format to JSON:
                with (output_dir / f"{doc_filename}.json").open("w") as fp:
                    fp.write(json.dumps(conv_res.document.export_to_dict()))

                # Export Docling document format to markdown:
                with (output_dir / f"{doc_filename}.md").open("w") as fp:
                    fp.write(conv_res.document.export_to_markdown())

        elif conv_res.status == ConversionStatus.PARTIAL_SUCCESS:
            _log.info(
                f"Document {conv_res.input.file} was partially converted with the following errors:"
            )
            for item in conv_res.errors:
                _log.info(f"\t{item.error_message}")
            partial_success_count += 1
        else:
            _log.info(f"Document {conv_res.input.file} failed to convert.")
            failure_count += 1

    _log.info(
        f"Processed {success_count + partial_success_count + failure_count} docs, "
        f"of which {failure_count} failed "
        f"and {partial_success_count} were partially converted."
    )
    return success_count, partial_success_count, failure_count

# %%
def main():
    logging.basicConfig(level=logging.INFO)

    input_doc_paths = [
        Path("./pdfs/Beyond Active and Passive Investing_ The Customization of Finance.pdf"),
        Path("./pdfs/Investment Model Validation_ A Guide for Practitioners.pdf"),
        Path("./pdfs/The Economics of Private Equity_ A Critical Review.pdf")
    ]

    # buf = BytesIO(Path("./test/data/2206.01062.pdf").open("rb").read())
    # docs = [DocumentStream(name="my_doc.pdf", stream=buf)]
    # input = DocumentConversionInput.from_streams(docs)

    # # Turn on inline debug visualizations:
    # settings.debug.visualize_layout = True
    # settings.debug.visualize_ocr = True
    # settings.debug.visualize_tables = True
    # settings.debug.visualize_cells = True
    pipeline_options = PdfPipelineOptions()
    pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
    pipeline_options.generate_page_images = False
    pipeline_options.generate_table_images = True
    pipeline_options.generate_picture_images = True

    doc_converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
        }
    )

    start_time = time.time()

    conv_results = doc_converter.convert_all(
        input_doc_paths,
        raises_on_error=False,  # to let conversion run through all and examine results at the end
    )
    
    success_count, partial_success_count, failure_count = export_documents(
        conv_results, output_dir=Path("Output")
    )

    end_time = time.time() - start_time

    _log.info(f"Document conversion complete in {end_time:.2f} seconds.")

    if failure_count > 0:
        raise RuntimeError(
            f"The example failed converting {failure_count} on {len(input_doc_paths)}."
        )

# %%
if __name__ == "__main__":
    main()

# %%
import json
import logging
import time
from pathlib import Path
from typing import Iterable


from docling.datamodel.base_models import ConversionStatus,InputFormat
from docling.datamodel.document import ConversionResult
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.settings import settings
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling_core.types.doc import ImageRefMode, PictureItem, TableItem

_log = logging.getLogger(__name__)

IMAGE_RESOLUTION_SCALE = 2.0
USE_V2 = True

def export_documents(
    conv_results: Iterable[ConversionResult],
    output_dir: Path,
):
    # Define paths for markdown and images
    markdown_output_dir = output_dir
    images_output_dir = output_dir / "images"

    # Ensure directories exist
    markdown_output_dir.mkdir(parents=True, exist_ok=True)
    images_output_dir.mkdir(parents=True, exist_ok=True)

    success_count = 0
    failure_count = 0
    partial_success_count = 0

    for conv_res in conv_results:
        if conv_res.status == ConversionStatus.SUCCESS:
            success_count += 1
            doc_filename = conv_res.input.file.stem

            # Export JSON, YAML, doctags, markdown, and text
            # if USE_V2:
            #     with (output_dir / f"{doc_filename}.json").open("w") as fp:
            #         fp.write(json.dumps(conv_res.document.export_to_dict()))

            #     # with (output_dir / f"{doc_filename}.yaml").open("w") as fp:
            #     #     fp.write(yaml.safe_dump(conv_res.document.export_to_dict()))

            #     # with (output_dir / f"{doc_filename}.doctags.txt").open("w") as fp:
            #     #     fp.write(conv_res.document.export_to_document_tokens())

            #     with (output_dir / f"{doc_filename}.md").open("w") as fp:
            #         fp.write(conv_res.document.export_to_markdown())

            #     # with (output_dir / f"{doc_filename}.txt").open("w") as fp:
            #     #     fp.write(conv_res.document.export_to_markdown(strict_text=True))

            # Export images for each page, table, and figure
            # for page_no, page in conv_res.document.pages.items():
            #     page_image_filename = output_dir / f"{doc_filename}-page-{page_no}.png"
            #     with page_image_filename.open("wb") as fp:
            #         page.image.pil_image.save(fp, format="PNG")

            table_counter = 0
            picture_counter = 0
            for element, _ in conv_res.document.iterate_items():
                if isinstance(element, TableItem):
                    table_counter += 1
                    element_image_filename = (
                        images_output_dir / f"{doc_filename}-table-{table_counter}.png"
                    )
                    with element_image_filename.open("wb") as fp:
                        element.image.pil_image.save(fp, "PNG")

                if isinstance(element, PictureItem):
                    picture_counter += 1
                    element_image_filename = (
                        images_output_dir / f"{doc_filename}-picture-{picture_counter}.png"
                    )
                    with element_image_filename.open("wb") as fp:
                        element.image.pil_image.save(fp, "PNG")

            # Export markdown with embedded images
            content_md = conv_res.document.export_to_markdown(image_mode=ImageRefMode.EMBEDDED)
            md_filename = markdown_output_dir / f"{doc_filename}-with-images.md"
            json_filename=markdown_output_dir / f"{doc_filename}-with-images.json"
            with md_filename.open("w") as fp:
                fp.write(content_md)
            with json_filename.open("w") as fp:
                fp.write(json.dumps(conv_res.document.export_to_dict()))
                

        elif conv_res.status == ConversionStatus.PARTIAL_SUCCESS:
            _log.info(f"Document {conv_res.input.file} was partially converted with errors:")
            for item in conv_res.errors:
                _log.info(f"\t{item.error_message}")
            partial_success_count += 1
        else:
            _log.info(f"Document {conv_res.input.file} failed to convert.")
            failure_count += 1

    _log.info(
        f"Processed {success_count + partial_success_count + failure_count} docs, "
        f"of which {failure_count} failed and {partial_success_count} were partially converted."
    )
    return success_count, partial_success_count, failure_count

# %%
def main():
    logging.basicConfig(level=logging.INFO)

    # PDF paths
    input_doc_paths = [
        Path("./pdfs/Beyond Active and Passive Investing_ The Customization of Finance.pdf"),
        Path("./pdfs/Investment Model Validation_ A Guide for Practitioners.pdf"),
        Path("./pdfs/The Economics of Private Equity_ A Critical Review.pdf"),
    ]

    # Setup PDF pipeline options for image scaling and generation
    pipeline_options = PdfPipelineOptions()
    pipeline_options.images_scale = IMAGE_RESOLUTION_SCALE
    pipeline_options.generate_page_images = False
    pipeline_options.generate_table_images = True
    pipeline_options.generate_picture_images = True

    doc_converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
        }
    )

    start_time = time.time()

    # Convert all documents
    conv_results = doc_converter.convert_all(input_doc_paths, raises_on_error=False)
    success_count, partial_success_count, failure_count = export_documents(
        conv_results, output_dir=Path("output")
    )

    end_time = time.time() - start_time
    _log.info(f"Document conversion complete in {end_time:.2f} seconds.")

    if failure_count > 0:
        raise RuntimeError(
            f"The conversion failed for {failure_count} out of {len(input_doc_paths)} documents."
        )

# %%
if __name__ == "__main__":
    main()
# Out:
# INFO:docling.document_converter:Going to convert document batch...
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# INFO:docling.pipeline.base_pipeline:Processing document Beyond Active and Passive Investing_ The Customization of Finance.pdf
# INFO:docling.document_converter:Finished converting document Beyond Active and Passive Investing_ The Customization of Finance.pdf in 55.04 sec.
# INFO:docling.pipeline.base_pipeline:Processing document Investment Model Validation_ A Guide for Practitioners.pdf
# INFO:docling.document_converter:Finished converting document Investment Model Validation_ A Guide for Practitioners.pdf in 34.23 sec.
# INFO:docling.document_converter:Going to convert document batch...
# INFO:docling.pipeline.base_pipeline:Processing document The Economics of Private Equity_ A Critical Review.pdf
# INFO:docling.document_converter:Finished converting document The Economics of Private Equity_ A Critical Review.pdf in 30.22 sec.
# INFO:__main__:Processed 3 docs, of which 0 failed and 0 were partially converted.
# INFO:__main__:Document conversion complete in 119.66 seconds.

# %%
import os
import json
import pinecone
import openai
from pathlib import Path
from typing import List, Dict
from pinecone import Pinecone, ServerlessSpec
from dotenv import load_dotenv

load_dotenv(override=True)

# Set up OpenAI and Pinecone API keys
pinecone = Pinecone(api_key=os.getenv("PINECONE_API_KEY"))

index_name = "document-embedding-index"

# Initialize Pinecone index (create if it doesn't exist)
if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        name=index_name,
        dimension=1536,
        metric="cosine",
        spec=ServerlessSpec(
            cloud="aws",
            region="us-east-1"
        ) 
    )
index = pinecone.Index(index_name)
# Out:
# INFO:pinecone_plugin_interface.logging:Discovering subpackages in _NamespacePath(['/Users/udaykiran/Library/Caches/pypoetry/virtualenvs/a4-vItfbIzM-py3.12/lib/python3.12/site-packages/pinecone_plugins'])
# INFO:pinecone_plugin_interface.logging:Looking for plugins in pinecone_plugins.inference
# INFO:pinecone_plugin_interface.logging:Installing plugin inference into Pinecone

# %%
import os
from pathlib import Path
import json
import numpy as np
from typing import Dict, List, Optional
import pinecone
from openai import OpenAI
from tqdm import tqdm
import base64
from PIL import Image
from io import BytesIO
import logging
from time import sleep

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('vectorization.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class CFADocumentVectorizer:
    def __init__(
        self,
        openai_api_key: str,
        pinecone_api_key: str,
        index_name: str = "cfa-research",
        namespace: str = "investment_research"
    ):
        # Initialize OpenAI client
        self.client = OpenAI(api_key=openai_api_key)
        self.embedding_model = "text-embedding-3-small"
        
        # Initialize Pinecone
        self.pc = Pinecone(api_key=pinecone_api_key)
        try:
            # Check if index exists
            index_list = self.pc.list_indexes()
            logger.info(f"Existing indexes: {index_list}")

            # Check if index exists in the list
            existing_indexes = index_list.get('indexes', [])
            index_exists = any(idx.get('name') == index_name for idx in existing_indexes)
            
            if index_exists:
                logger.info(f"Deleting existing index: {index_name}")
                self.pc.delete_index(index_name)
                # Wait a bit after deletion
                sleep(5)
                logger.info(f"Deleted index: {index_name}")

            # Create new index
            logger.info(f"Creating new index: {index_name}")
            self.pc.create_index(
                name=index_name,
                dimension=1536,
                metric="cosine",
                spec=ServerlessSpec(
                    cloud="aws",
                    region="us-east-1"
                )
            )
            
            # Wait for index to be ready
            retry_count = 0
            max_retries = 60  # Maximum 1 minute wait
            while retry_count < max_retries:
                try:
                    index_info = self.pc.describe_index(index_name)
                    if index_info.get('status', {}).get('ready', False):
                        break
                except Exception as e:
                    logger.warning(f"Waiting for index to be ready... {str(e)}")
                sleep(1)
                retry_count += 1
                
            if retry_count >= max_retries:
                raise TimeoutError("Index creation timed out")
                
            logger.info(f"Index {index_name} is ready")
            
            self.index = self.pc.Index(index_name)
            self.namespace = namespace
            
            # Set up paths
            self.output_dir = Path("./output")
            self.images_dir = self.output_dir / "images"
            
        except Exception as e:
            logger.error(f"Error initializing Pinecone: {str(e)}")
            raise


    def load_document(self, json_path: Path) -> Dict:
        """Load and validate JSON document"""
        try:
            with open(json_path) as f:
                doc_data = json.load(f)
            logger.info(f"Successfully loaded document: {json_path.name}")
            return doc_data
        except Exception as e:
            logger.error(f"Error loading document {json_path}: {e}")
            raise

    def create_embedding(self, text: str) -> List[float]:
        """Create embedding with rate limiting and retries"""
        max_retries = 3
        for attempt in range(max_retries):
            try:
                response = self.client.embeddings.create(
                    input=text,
                    model=self.embedding_model
                )
                return response.data[0].embedding
            except Exception as e:
                if attempt == max_retries - 1:
                    logger.error(f"Failed to create embedding after {max_retries} attempts: {e}")
                    raise
                sleep(2 ** attempt)  # Exponential backoff
                continue

    def process_text_block(self, text_block: Dict, doc_name: str, current_section: str) -> Dict:
        """Process a single text block with section context"""
        text_content = text_block['text']
        label = text_block['label']
        prov = text_block['prov'][0]
        prov = text_block['prov'][0]  # Access first element of prov list
        page_no = prov['page_no']
        bbox = prov['bbox']
        # page_no = text_block['prov']['0']['page_no']
        # bbox = text_block['prov']['0']['bbox']
        # Convert bbox to string format for Pinecone metadata
        bbox_str = f"{bbox['l']:.2f},{bbox['t']:.2f},{bbox['r']:.2f},{bbox['b']:.2f}"
        try:
            embedding = self.create_embedding(text_content)
            
            return {
                'id': f"{doc_name}_text_{text_block['self_ref'].split('/')[-1]}",
                'values': embedding,
                'metadata': {
                    'doc_name': doc_name,
                    'content_type': 'text',
                    'label': label,
                    'page_no': page_no,
                    'text': text_content[:1000],  ##CHECK IF TO USE OR NOT # Limit metadata text length
                    'bbox': bbox_str,
                    'section': current_section
                }
            }
        except Exception as e:
            logger.error(f"Error processing text block: {e}")
            logger.error(f"Text block structure: {text_block}")
            return None
    def process_table(self, table: Dict, doc_name: str) -> List[Dict]:
        """Process table data and corresponding image"""
        vectors = []
        table_id = table['self_ref'].split('/')[-1]
        prov = table['prov'][0]  # Access first element of prov list
        page_no = prov['page_no']
        bbox = prov['bbox']  # Get bbox from prov
        bbox_str = f"{bbox['l']:.2f},{bbox['t']:.2f},{bbox['r']:.2f},{bbox['b']:.2f}"
        
        # Get table image path
        table_image_path = self.images_dir / f"{doc_name}-table-{int(table_id)+1}.png"
        
        # Process structured table data
        if 'data' in table and 'table_cells' in table['data']:
            table_text = []
            for cell in table['data']['grid']:
                if 'text' in cell:
                    table_text.append(cell['text'])
            
            if table_text:
                try:
                    text_embedding = self.create_embedding(" ".join(table_text))
                    
                    vectors.append({
                        'id': f"{doc_name}_table_{table_id}_text",
                        'values': text_embedding,
                        'metadata': {
                            'doc_name': doc_name,
                            'content_type': 'table_text',
                            'page_no': page_no,
                            'text': " ".join(table_text)[:1000],
                            'bbox': bbox_str,  # Add bbox to metadata
                            'table_structure': {
                                'num_rows': table['data']['table_cells']['num_rows'],
                                'num_cols': table['data']['table_cells']['num_cols']
                            },
                            'image_path': str(table_image_path)
                        }
                    })
                except Exception as e:
                    logger.error(f"Error processing table text: {e}")

        # Process table image if it exists
        if table_image_path.exists():
            try:
                with open(table_image_path, 'rb') as img_file:
                    image_data = img_file.read()
                    
                response = self.client.chat.completions.create(
                    model="gpt-4o",
                    messages=[
                        {
                            "role": "user",
                            "content": [
                                {"type": "text", "text": "Describe this table's content and structure in detail."},
                                {"type": "image_url",
                                "image_url": {"url": f"data:image/png;base64,{base64.b64encode(image_data).decode()}"}}
                            ]
                        }
                    ],
                    max_tokens=300
                )
                
                image_description = response.choices[0].message.content
                image_embedding = self.create_embedding(image_description)
                
                vectors.append({
                    'id': f"{doc_name}_table_{table_id}_image",
                    'values': image_embedding,
                    'metadata': {
                        'doc_name': doc_name,
                        'content_type': 'table_image',
                        'page_no': page_no,
                        'bbox': bbox_str,  # Add bbox to metadata
                        'description': image_description,
                        'image_path': str(table_image_path)
                    }
                })
            except Exception as e:
                logger.error(f"Error processing table image {table_image_path}: {e}")

        return vectors

    def process_picture(self, picture: Dict, doc_name: str) -> Optional[Dict]:
        """Process picture using the extracted image file"""
        try:
            picture_id = picture['self_ref'].split('/')[-1]
            prov = picture['prov'][0]  # Access first element of prov list
            page_no = prov['page_no']
            bbox = prov['bbox']  # Get bbox from prov
            bbox_str = f"{bbox['l']:.2f},{bbox['t']:.2f},{bbox['r']:.2f},{bbox['b']:.2f}"
            
            picture_path = self.images_dir / f"{doc_name}-picture-{int(picture_id)+1}.png"
            
            if not picture_path.exists():
                logger.warning(f"Picture file not found: {picture_path}")
                return None
                
            with open(picture_path, 'rb') as img_file:
                image_data = img_file.read()
                
            # Get image description using GPT-4 Vision
            response = self.client.chat.completions.create(
                model="gpt-4o",
                messages=[
                    {
                        "role": "user",
                        "content": [
                            {"type": "text", "text": "Describe this image in detail, including any text or diagrams visible."},
                            {"type": "image_url",
                            "image_url": {"url": f"data:image/png;base64,{base64.b64encode(image_data).decode()}"}}
                        ]
                    }
                ],
                max_tokens=300
            )
            
            image_description = response.choices[0].message.content
            
            # Create embedding for the description
            embedding = self.create_embedding(image_description)
            
            return {
                'id': f"{doc_name}_picture_{picture_id}",
                'values': embedding,
                'metadata': {
                    'doc_name': doc_name,
                    'content_type': 'picture',
                    'page_no': page_no,
                    'bbox': bbox_str,  # Add bbox to metadata
                    'description': image_description,
                    'image_path': str(picture_path)
                }
            }
        except Exception as e:
            logger.error(f"Error processing picture {picture_id}: {str(e)}")
            logger.error(f"Picture structure: {picture}")
            return None

    def process_document(self, json_path: Path) -> None:
        """Process complete document including all its components"""
        doc_data = self.load_document(json_path)
        doc_name = doc_data['name']
        current_section = "introduction"
        vectors_to_upsert = []
        
        logger.info(f"Processing document: {doc_name}")
        
        # Process text blocks
        logger.info("Processing text blocks...")
        for text_block in tqdm(doc_data['texts'], desc="Text blocks"):
            # Update section if section header
            if text_block['label'] == 'section_header':
                current_section = text_block['text']
                
            vector = self.process_text_block(text_block, doc_name, current_section)
            if vector:
                vectors_to_upsert.append(vector)
                
                if len(vectors_to_upsert) >= 100:
                    self.index.upsert(vectors=vectors_to_upsert, namespace=self.namespace)
                    vectors_to_upsert = []
                    sleep(1)  # Rate limiting
        
        # Process tables
        logger.info("Processing tables...")
        for table in tqdm(doc_data['tables'], desc="Tables"):
            table_vectors = self.process_table(table, doc_name)
            vectors_to_upsert.extend(table_vectors)
            
            if len(vectors_to_upsert) >= 100:
                self.index.upsert(vectors=vectors_to_upsert, namespace=self.namespace)
                vectors_to_upsert = []
                sleep(1)  # Rate limiting
        
        # Process pictures
        logger.info("Processing pictures...")
        for picture in tqdm(doc_data['pictures'], desc="Pictures"):
            vector = self.process_picture(picture, doc_name)
            if vector:
                vectors_to_upsert.append(vector)
                
                if len(vectors_to_upsert) >= 100:
                    self.index.upsert(vectors=vectors_to_upsert, namespace=self.namespace)
                    vectors_to_upsert = []
                    sleep(1)  # Rate limiting
        
        # Upsert any remaining vectors
        if vectors_to_upsert:
            self.index.upsert(vectors=vectors_to_upsert, namespace=self.namespace)
        
        logger.info(f"Completed processing document: {doc_name}")

def main():
    """Process all documents in the output directory"""
    try:
        # Load environment variables
        from dotenv import load_dotenv
        load_dotenv()
        
        openai_api_key = os.getenv("OPENAI_API_KEY")
        pinecone_api_key = os.getenv("PINECONE_API_KEY")
        #pinecone_env = os.getenv("PINECONE_ENV")
        
        if not all([openai_api_key, pinecone_api_key]):
            raise ValueError("Missing required environment variables")
        
        # Initialize vectorizer
        vectorizer = CFADocumentVectorizer(
            openai_api_key=openai_api_key,
            pinecone_api_key=pinecone_api_key
        )
        
        # Process all JSON files in output directory
        output_dir = Path("./output")
        json_files = list(output_dir.glob("*-with-images.json"))
        
        logger.info(f"Found {len(json_files)} documents to process")
        
        for json_file in json_files:
            try:
                logger.info(f"\nProcessing {json_file.name}")
                vectorizer.process_document(json_file)
            except Exception as e:
                logger.error(f"Error processing document {json_file.name}: {e}")
                continue
        
        logger.info("Completed processing all documents")
        
    except Exception as e:
        logger.error(f"Error in main process: {e}")
        raise

if __name__ == "__main__":
    main()
# Out:
# INFO:pinecone_plugin_interface.logging:Discovering subpackages in _NamespacePath(['/Users/udaykiran/Library/Caches/pypoetry/virtualenvs/a4-vItfbIzM-py3.12/lib/python3.12/site-packages/pinecone_plugins'])
# INFO:pinecone_plugin_interface.logging:Looking for plugins in pinecone_plugins.inference
# INFO:pinecone_plugin_interface.logging:Installing plugin inference into Pinecone
# INFO:__main__:Existing indexes: {'indexes': [{'deletion_protection': 'disabled',
#               'dimension': 1536,
#               'host': 'cfa-research-gu6zp0z.svc.aped-4627-b74a.pinecone.io',
#               'metric': 'cosine',
#               'name': 'cfa-research',
#               'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#               'status': {'ready': True, 'state': 'Ready'}}]}
# INFO:__main__:Deleting existing index: cfa-research
# INFO:__main__:Deleted index: cfa-research
# INFO:__main__:Creating new index: cfa-research
# INFO:__main__:Index cfa-research is ready
# INFO:__main__:Found 1 documents to process
# INFO:__main__:
# Processing Beyond Active and Passive Investing_ The Customization of Finance-with-images.json
# INFO:__main__:Successfully loaded document: Beyond Active and Passive Investing_ The Customization of Finance-with-images.json
# INFO:__main__:Processing document: Beyond Active and Passive Investing_ The Customization of Finance
# INFO:__main__:Processing text blocks...
# Text blocks:   0%|          | 0/828 [00:00<?, ?it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   0%|          | 1/828 [00:00<02:55,  4.70it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   0%|          | 2/828 [00:00<03:15,  4.23it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   0%|          | 3/828 [00:00<02:46,  4.97it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   0%|          | 4/828 [00:00<02:26,  5.61it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|          | 5/828 [00:00<02:40,  5.14it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|          | 6/828 [00:01<02:50,  4.82it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|          | 7/828 [00:01<02:42,  5.06it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|          | 8/828 [00:01<02:20,  5.83it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|          | 9/828 [00:01<02:37,  5.21it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|          | 10/828 [00:02<03:06,  4.39it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|▏         | 11/828 [00:02<03:26,  3.96it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   1%|▏         | 12/828 [00:02<03:38,  3.73it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 13/828 [00:02<03:28,  3.92it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 14/828 [00:03<03:35,  3.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 15/828 [00:03<03:31,  3.84it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 16/828 [00:03<03:33,  3.80it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 17/828 [00:03<03:35,  3.76it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 18/828 [00:04<04:17,  3.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 19/828 [00:04<03:33,  3.80it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   2%|▏         | 20/828 [00:04<03:21,  4.00it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 21/828 [00:04<03:15,  4.12it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 22/828 [00:05<02:50,  4.73it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 23/828 [00:05<02:48,  4.77it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 24/828 [00:05<02:29,  5.39it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 25/828 [00:05<02:51,  4.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 26/828 [00:05<02:55,  4.58it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 27/828 [00:06<03:34,  3.74it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   3%|▎         | 28/828 [00:06<03:11,  4.18it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▎         | 29/828 [00:06<02:53,  4.60it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▎         | 30/828 [00:07<03:31,  3.77it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▎         | 31/828 [00:07<02:56,  4.50it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▍         | 32/828 [00:07<02:54,  4.56it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▍         | 33/828 [00:07<02:29,  5.31it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▍         | 34/828 [00:07<02:48,  4.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▍         | 35/828 [00:08<02:55,  4.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▍         | 36/828 [00:08<03:01,  4.38it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   4%|▍         | 37/828 [00:08<03:01,  4.35it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▍         | 38/828 [00:08<03:18,  3.98it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▍         | 39/828 [00:08<02:52,  4.58it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▍         | 40/828 [00:09<02:53,  4.53it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▍         | 41/828 [00:09<02:53,  4.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▌         | 42/828 [00:09<02:56,  4.46it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▌         | 43/828 [00:09<03:15,  4.01it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▌         | 44/828 [00:10<03:15,  4.00it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   5%|▌         | 45/828 [00:10<02:45,  4.72it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▌         | 46/828 [00:10<02:21,  5.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▌         | 47/828 [00:10<02:57,  4.40it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▌         | 48/828 [00:10<02:32,  5.13it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▌         | 49/828 [00:11<02:54,  4.46it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▌         | 50/828 [00:11<02:52,  4.51it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▌         | 51/828 [00:11<02:29,  5.19it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▋         | 52/828 [00:11<02:33,  5.04it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   6%|▋         | 53/828 [00:11<02:15,  5.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 54/828 [00:12<02:55,  4.41it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 55/828 [00:12<03:38,  3.54it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 56/828 [00:12<03:43,  3.46it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 57/828 [00:13<03:05,  4.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 58/828 [00:13<03:06,  4.13it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 59/828 [00:13<02:59,  4.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 60/828 [00:13<02:54,  4.41it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 61/828 [00:14<03:16,  3.89it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   7%|▋         | 62/828 [00:14<03:12,  3.99it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 63/828 [00:14<03:01,  4.21it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 64/828 [00:14<03:00,  4.23it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 65/828 [00:15<03:26,  3.70it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 66/828 [00:15<03:33,  3.56it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 67/828 [00:15<03:30,  3.62it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 68/828 [00:15<03:06,  4.08it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 69/828 [00:16<03:14,  3.91it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   8%|▊         | 70/828 [00:16<03:04,  4.12it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▊         | 71/828 [00:16<02:51,  4.42it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▊         | 72/828 [00:16<02:32,  4.97it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▉         | 73/828 [00:16<02:48,  4.48it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▉         | 74/828 [00:17<03:07,  4.02it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▉         | 75/828 [00:17<02:55,  4.30it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▉         | 76/828 [00:17<02:34,  4.87it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▉         | 77/828 [00:17<02:36,  4.80it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:   9%|▉         | 78/828 [00:18<02:50,  4.39it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|▉         | 79/828 [00:18<02:43,  4.58it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|▉         | 80/828 [00:18<02:35,  4.81it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|▉         | 81/828 [00:18<02:26,  5.09it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|▉         | 82/828 [00:18<02:40,  4.64it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|█         | 83/828 [00:19<02:58,  4.18it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|█         | 84/828 [00:19<03:16,  3.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|█         | 85/828 [00:19<03:26,  3.59it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  10%|█         | 86/828 [00:20<03:14,  3.81it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█         | 87/828 [00:20<03:01,  4.08it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█         | 88/828 [00:20<03:21,  3.67it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█         | 89/828 [00:20<02:46,  4.44it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█         | 90/828 [00:20<02:37,  4.69it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█         | 91/828 [00:21<02:50,  4.33it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█         | 92/828 [00:21<02:49,  4.34it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█         | 93/828 [00:21<02:24,  5.07it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█▏        | 94/828 [00:21<02:06,  5.79it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  11%|█▏        | 95/828 [00:21<02:12,  5.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 96/828 [00:22<02:49,  4.31it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 97/828 [00:22<03:05,  3.93it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 98/828 [00:22<03:16,  3.72it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 99/828 [00:23<03:25,  3.54it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 100/828 [00:25<10:27,  1.16it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 101/828 [00:25<08:05,  1.50it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 102/828 [00:25<06:07,  1.97it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  12%|█▏        | 103/828 [00:25<05:04,  2.38it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 104/828 [00:25<03:58,  3.04it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 105/828 [00:26<03:46,  3.20it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 106/828 [00:26<03:17,  3.66it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 107/828 [00:26<03:29,  3.44it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 108/828 [00:26<02:58,  4.03it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 109/828 [00:27<02:36,  4.60it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 110/828 [00:27<02:58,  4.03it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  13%|█▎        | 111/828 [00:27<03:10,  3.77it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▎        | 112/828 [00:27<02:52,  4.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▎        | 113/828 [00:28<02:44,  4.35it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▍        | 114/828 [00:28<03:27,  3.44it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▍        | 115/828 [00:28<03:14,  3.66it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▍        | 116/828 [00:28<03:01,  3.93it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▍        | 117/828 [00:29<02:50,  4.16it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▍        | 118/828 [00:29<02:27,  4.80it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▍        | 119/828 [00:29<02:36,  4.53it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  14%|█▍        | 120/828 [00:29<02:37,  4.49it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▍        | 121/828 [00:29<02:17,  5.13it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▍        | 122/828 [00:30<02:26,  4.82it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▍        | 123/828 [00:30<03:10,  3.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▍        | 124/828 [00:31<04:10,  2.81it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▌        | 125/828 [00:31<03:51,  3.03it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▌        | 126/828 [00:31<03:24,  3.43it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▌        | 127/828 [00:31<02:57,  3.94it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  15%|█▌        | 128/828 [00:32<03:21,  3.47it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▌        | 129/828 [00:32<03:03,  3.80it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▌        | 130/828 [00:32<02:59,  3.90it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▌        | 131/828 [00:32<02:47,  4.17it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▌        | 132/828 [00:32<02:36,  4.45it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▌        | 133/828 [00:33<02:28,  4.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▌        | 134/828 [00:33<02:15,  5.12it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▋        | 135/828 [00:33<02:00,  5.73it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  16%|█▋        | 136/828 [00:33<02:00,  5.73it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 137/828 [00:33<02:48,  4.09it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 138/828 [00:34<02:49,  4.07it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 139/828 [00:34<02:46,  4.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 140/828 [00:34<02:31,  4.54it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 141/828 [00:34<02:15,  5.06it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 142/828 [00:35<03:12,  3.56it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 143/828 [00:35<02:54,  3.93it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  17%|█▋        | 144/828 [00:35<03:07,  3.65it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 145/828 [00:36<03:13,  3.53it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 146/828 [00:36<02:56,  3.87it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 147/828 [00:36<02:43,  4.17it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 148/828 [00:36<02:35,  4.37it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 149/828 [00:36<02:24,  4.70it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 150/828 [00:37<02:16,  4.98it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 151/828 [00:37<02:53,  3.91it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 152/828 [00:37<03:03,  3.69it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  18%|█▊        | 153/828 [00:38<03:10,  3.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▊        | 154/828 [00:38<02:49,  3.98it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▊        | 155/828 [00:38<02:34,  4.36it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▉        | 156/828 [00:38<02:24,  4.64it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▉        | 157/828 [00:38<02:37,  4.26it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▉        | 158/828 [00:38<02:11,  5.09it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▉        | 159/828 [00:39<02:01,  5.50it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▉        | 160/828 [00:39<02:09,  5.17it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  19%|█▉        | 161/828 [00:39<02:09,  5.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|█▉        | 162/828 [00:39<02:18,  4.83it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|█▉        | 163/828 [00:39<02:19,  4.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|█▉        | 164/828 [00:40<02:39,  4.17it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|█▉        | 165/828 [00:40<02:52,  3.85it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|██        | 166/828 [00:40<03:21,  3.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|██        | 167/828 [00:41<02:56,  3.75it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|██        | 168/828 [00:41<03:06,  3.54it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  20%|██        | 169/828 [00:41<02:53,  3.80it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██        | 170/828 [00:41<02:50,  3.86it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██        | 171/828 [00:42<02:27,  4.45it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██        | 172/828 [00:42<02:25,  4.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██        | 173/828 [00:42<02:23,  4.57it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██        | 174/828 [00:42<02:12,  4.95it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██        | 175/828 [00:43<02:41,  4.06it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██▏       | 176/828 [00:43<02:52,  3.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██▏       | 177/828 [00:43<02:45,  3.92it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  21%|██▏       | 178/828 [00:44<05:49,  1.86it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 179/828 [00:45<05:04,  2.13it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 180/828 [00:45<04:09,  2.60it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 181/828 [00:45<03:22,  3.20it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 182/828 [00:45<03:35,  2.99it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 183/828 [00:45<02:58,  3.61it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 184/828 [00:46<02:45,  3.89it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 185/828 [00:46<03:05,  3.46it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  22%|██▏       | 186/828 [00:46<02:42,  3.96it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 187/828 [00:46<02:19,  4.59it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 188/828 [00:47<02:34,  4.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 189/828 [00:47<02:49,  3.76it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 190/828 [00:47<03:10,  3.35it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 191/828 [00:48<03:18,  3.21it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 192/828 [00:48<03:08,  3.37it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 193/828 [00:48<02:36,  4.05it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  23%|██▎       | 194/828 [00:48<02:30,  4.22it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▎       | 195/828 [00:48<02:10,  4.84it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▎       | 196/828 [00:49<02:13,  4.75it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▍       | 197/828 [00:49<02:13,  4.72it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▍       | 198/828 [00:49<02:33,  4.11it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▍       | 199/828 [00:49<02:18,  4.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▍       | 200/828 [00:51<07:16,  1.44it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▍       | 201/828 [00:52<06:25,  1.63it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  24%|██▍       | 202/828 [00:52<04:55,  2.12it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▍       | 203/828 [00:52<04:07,  2.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▍       | 204/828 [00:52<03:22,  3.08it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▍       | 205/828 [00:52<03:18,  3.14it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▍       | 206/828 [00:53<02:56,  3.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▌       | 207/828 [00:53<03:20,  3.10it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▌       | 208/828 [00:53<03:02,  3.40it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▌       | 209/828 [00:53<02:39,  3.88it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▌       | 210/828 [00:54<02:30,  4.10it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  25%|██▌       | 211/828 [00:54<02:54,  3.54it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▌       | 212/828 [00:54<03:09,  3.26it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▌       | 213/828 [00:54<02:38,  3.87it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▌       | 214/828 [00:55<02:38,  3.88it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▌       | 215/828 [00:55<02:45,  3.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▌       | 216/828 [00:55<02:22,  4.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▌       | 217/828 [00:55<02:08,  4.76it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▋       | 218/828 [00:56<02:25,  4.18it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  26%|██▋       | 219/828 [00:56<02:03,  4.94it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 220/828 [00:56<01:44,  5.82it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 221/828 [00:56<02:08,  4.74it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 222/828 [00:56<02:09,  4.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 223/828 [00:57<02:22,  4.25it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 224/828 [00:57<02:15,  4.45it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 225/828 [00:57<02:20,  4.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 226/828 [00:57<02:07,  4.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  27%|██▋       | 227/828 [00:58<02:24,  4.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 228/828 [00:58<02:22,  4.20it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 229/828 [00:58<02:30,  3.99it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 230/828 [00:58<02:22,  4.20it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 231/828 [00:58<02:16,  4.39it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 232/828 [00:59<02:47,  3.56it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 233/828 [00:59<02:20,  4.25it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 234/828 [00:59<02:46,  3.57it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  28%|██▊       | 235/828 [01:00<02:34,  3.84it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▊       | 236/828 [01:00<02:58,  3.32it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▊       | 237/828 [01:00<02:59,  3.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▊       | 238/828 [01:00<02:27,  4.00it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▉       | 239/828 [01:01<02:51,  3.44it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▉       | 240/828 [01:01<02:19,  4.21it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▉       | 241/828 [01:01<01:56,  5.05it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▉       | 242/828 [01:01<01:59,  4.89it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▉       | 243/828 [01:02<02:01,  4.80it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  29%|██▉       | 244/828 [01:02<01:58,  4.92it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|██▉       | 245/828 [01:02<01:56,  4.99it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|██▉       | 246/828 [01:02<01:59,  4.88it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|██▉       | 247/828 [01:02<02:17,  4.23it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|██▉       | 248/828 [01:03<02:07,  4.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|███       | 249/828 [01:03<02:06,  4.57it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|███       | 250/828 [01:03<01:48,  5.33it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|███       | 251/828 [01:06<09:26,  1.02it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  30%|███       | 252/828 [01:06<07:08,  1.34it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███       | 253/828 [01:06<05:36,  1.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███       | 254/828 [01:06<04:29,  2.13it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███       | 255/828 [01:07<03:33,  2.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███       | 256/828 [01:07<03:16,  2.91it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███       | 257/828 [01:07<02:37,  3.64it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███       | 258/828 [01:07<02:25,  3.93it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███▏      | 259/828 [01:07<02:09,  4.39it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  31%|███▏      | 260/828 [01:07<02:04,  4.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 261/828 [01:08<02:23,  3.94it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 262/828 [01:08<02:12,  4.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 263/828 [01:08<02:16,  4.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 264/828 [01:08<01:53,  4.97it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 265/828 [01:09<01:54,  4.94it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 266/828 [01:09<01:56,  4.82it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 267/828 [01:09<01:44,  5.37it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 268/828 [01:09<02:07,  4.40it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  32%|███▏      | 269/828 [01:10<03:11,  2.92it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 270/828 [01:10<02:35,  3.58it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 271/828 [01:10<02:11,  4.24it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 272/828 [01:10<02:02,  4.53it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 273/828 [01:11<02:28,  3.74it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 274/828 [01:11<02:50,  3.25it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 275/828 [01:12<03:07,  2.95it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 276/828 [01:12<02:53,  3.19it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  33%|███▎      | 277/828 [01:12<02:39,  3.45it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▎      | 278/828 [01:12<02:20,  3.92it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▎      | 279/828 [01:12<02:08,  4.27it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▍      | 280/828 [01:12<01:48,  5.04it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▍      | 281/828 [01:13<01:37,  5.61it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▍      | 282/828 [01:13<01:26,  6.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▍      | 283/828 [01:13<01:26,  6.34it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▍      | 284/828 [01:13<01:45,  5.17it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  34%|███▍      | 285/828 [01:13<01:47,  5.06it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▍      | 286/828 [01:14<02:37,  3.45it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▍      | 287/828 [01:14<02:26,  3.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▍      | 288/828 [01:14<02:14,  4.02it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▍      | 289/828 [01:15<02:24,  3.72it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▌      | 290/828 [01:15<02:01,  4.43it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▌      | 291/828 [01:15<01:50,  4.84it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▌      | 292/828 [01:15<01:41,  5.30it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  35%|███▌      | 293/828 [01:15<01:27,  6.09it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▌      | 294/828 [01:16<03:54,  2.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▌      | 295/828 [01:16<03:15,  2.73it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▌      | 296/828 [01:17<03:11,  2.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▌      | 297/828 [01:17<03:03,  2.89it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▌      | 298/828 [01:17<03:08,  2.82it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▌      | 299/828 [01:18<02:39,  3.31it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▌      | 300/828 [01:20<07:37,  1.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▋      | 301/828 [01:20<06:07,  1.43it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  36%|███▋      | 302/828 [01:20<05:04,  1.73it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 303/828 [01:21<04:21,  2.01it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 304/828 [01:21<03:50,  2.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 305/828 [01:21<03:04,  2.84it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 306/828 [01:21<02:36,  3.33it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 307/828 [01:21<02:11,  3.95it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 308/828 [01:22<02:26,  3.56it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 309/828 [01:22<02:11,  3.96it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  37%|███▋      | 310/828 [01:22<02:22,  3.63it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  38%|███▊      | 311/828 [01:23<02:27,  3.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  38%|███▊      | 312/828 [01:23<02:08,  4.00it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  38%|███▊      | 313/828 [01:23<02:22,  3.60it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  38%|███▊      | 314/828 [01:23<01:57,  4.38it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  38%|███▊      | 315/828 [01:24<02:07,  4.03it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  38%|███▊      | 316/828 [01:24<01:47,  4.76it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ...
# Text blocks:  97%|█████████▋| 804/828 [03:36<00:08,  2.87it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  97%|█████████▋| 805/828 [03:36<00:08,  2.84it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  97%|█████████▋| 806/828 [03:36<00:06,  3.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  97%|█████████▋| 807/828 [03:38<00:13,  1.57it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 808/828 [03:38<00:10,  1.94it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 809/828 [03:38<00:07,  2.49it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 810/828 [03:39<00:06,  2.74it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 811/828 [03:39<00:05,  3.11it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 812/828 [03:39<00:04,  3.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 813/828 [03:39<00:04,  3.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 814/828 [03:39<00:03,  4.16it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  98%|█████████▊| 815/828 [03:40<00:02,  4.42it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▊| 816/828 [03:40<00:02,  4.48it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▊| 817/828 [03:40<00:02,  4.91it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▉| 818/828 [03:40<00:02,  4.53it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▉| 819/828 [03:41<00:02,  4.13it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▉| 820/828 [03:41<00:02,  3.19it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▉| 821/828 [03:41<00:01,  3.53it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▉| 822/828 [03:41<00:01,  3.98it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks:  99%|█████████▉| 823/828 [03:42<00:01,  4.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks: 100%|█████████▉| 824/828 [03:42<00:00,  4.95it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks: 100%|█████████▉| 825/828 [03:42<00:00,  4.87it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks: 100%|█████████▉| 826/828 [03:42<00:00,  5.72it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks: 100%|█████████▉| 827/828 [03:42<00:00,  5.64it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Text blocks: 100%|██████████| 828/828 [03:42<00:00,  3.71it/s]
# INFO:__main__:Processing tables...
# Tables:   0%|          | 0/13 [00:00<?, ?it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:   8%|▊         | 1/13 [00:06<01:14,  6.24s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  15%|█▌        | 2/13 [00:11<00:59,  5.40s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  23%|██▎       | 3/13 [00:18<01:05,  6.51s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  31%|███       | 4/13 [00:24<00:56,  6.26s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  38%|███▊      | 5/13 [00:31<00:52,  6.56s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  46%|████▌     | 6/13 [00:37<00:43,  6.14s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  54%|█████▍    | 7/13 [00:42<00:35,  5.87s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  62%|██████▏   | 8/13 [00:49<00:31,  6.22s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  69%|██████▉   | 9/13 [00:55<00:24,  6.23s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  77%|███████▋  | 10/13 [01:00<00:17,  5.91s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  85%|████████▍ | 11/13 [01:06<00:11,  5.75s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables:  92%|█████████▏| 12/13 [01:10<00:05,  5.42s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Tables: 100%|██████████| 13/13 [01:16<00:00,  5.88s/it]
# INFO:__main__:Processing pictures...
# Pictures:   0%|          | 0/39 [00:00<?, ?it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:   3%|▎         | 1/39 [00:05<03:16,  5.17s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:   5%|▌         | 2/39 [00:08<02:28,  4.02s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:   8%|▊         | 3/39 [00:11<02:16,  3.78s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  10%|█         | 4/39 [00:16<02:30,  4.30s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  13%|█▎        | 5/39 [00:20<02:18,  4.08s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  15%|█▌        | 6/39 [00:24<02:14,  4.09s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  18%|█▊        | 7/39 [00:31<02:39,  5.00s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  21%|██        | 8/39 [00:34<02:18,  4.46s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  23%|██▎       | 9/39 [00:39<02:12,  4.43s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  26%|██▌       | 10/39 [00:43<02:01,  4.20s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  28%|██▊       | 11/39 [00:48<02:08,  4.60s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  31%|███       | 12/39 [00:54<02:16,  5.07s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  33%|███▎      | 13/39 [01:03<02:38,  6.11s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  36%|███▌      | 14/39 [01:07<02:17,  5.51s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  38%|███▊      | 15/39 [01:10<01:58,  4.95s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  41%|████      | 16/39 [01:15<01:51,  4.83s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  44%|████▎     | 17/39 [01:21<01:54,  5.21s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  46%|████▌     | 18/39 [01:25<01:42,  4.86s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  49%|████▊     | 19/39 [01:30<01:39,  4.99s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  51%|█████▏    | 20/39 [01:37<01:42,  5.39s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  54%|█████▍    | 21/39 [01:42<01:35,  5.33s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  56%|█████▋    | 22/39 [01:50<01:44,  6.12s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  59%|█████▉    | 23/39 [01:54<01:26,  5.41s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  62%|██████▏   | 24/39 [01:58<01:16,  5.09s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  64%|██████▍   | 25/39 [02:02<01:07,  4.81s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  67%|██████▋   | 26/39 [02:06<00:57,  4.40s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  69%|██████▉   | 27/39 [02:09<00:49,  4.17s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  72%|███████▏  | 28/39 [02:14<00:47,  4.36s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  74%|███████▍  | 29/39 [02:20<00:47,  4.79s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  77%|███████▋  | 30/39 [02:24<00:42,  4.67s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  79%|███████▉  | 31/39 [02:29<00:37,  4.64s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  82%|████████▏ | 32/39 [02:33<00:31,  4.49s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  85%|████████▍ | 33/39 [02:38<00:27,  4.57s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  87%|████████▋ | 34/39 [02:43<00:23,  4.76s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  90%|████████▉ | 35/39 [02:48<00:19,  4.80s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  92%|█████████▏| 36/39 [02:52<00:14,  4.71s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  95%|█████████▍| 37/39 [03:00<00:10,  5.47s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures:  97%|█████████▋| 38/39 [03:02<00:04,  4.46s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Pictures: 100%|██████████| 39/39 [03:07<00:00,  4.80s/it]
# INFO:__main__:Completed processing document: Beyond Active and Passive Investing_ The Customization of Finance
# INFO:__main__:Completed processing all documents
